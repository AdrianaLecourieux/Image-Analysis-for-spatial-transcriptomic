# %% [markdown]
# # Visualization of tissue mask : xFuse

# %% [markdown]
# This script allow the visualization of mask from xFuse. We ran it in order to debug the tool. This didn't work.

# %%
# !python visualize_tissue_masks.py */data.h5
# Out:
# Figure(640x480)

# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np

# %%
parser = argparse.ArgumentParser()
parser.add_argument("data_files", nargs="+")
options = parser.parse_args()

n = len(options.data_files)
c = int(np.ceil(n ** 0.5))
r = int(np.ceil(n / c))
fig, axs = plt.subplots(r, c)
if n == 1:
    axs = np.array([axs])
for filename, ax in zip(options.data_files, axs.flatten()):
    with h5py.File(filename, "r") as data:
        img = (data["image"][()] + 1) / 2
        mask = data["label"][()] == 1
        img[mask] = 0.25 * img[mask]
        ax.imshow(img)
plt.tight_layout()
plt.show(

# %%
filename = "xfuse-2023-04-20T10:48:25.418334/data.h5"

# %%
n=1
fig, axs = plt.subplots(r, c)
if n == 1:
    axs = np.array([axs])
for filename, ax in zip(filename2, axs.flatten()):
    with h5py.File(filename, "r") as data:
        img = (data["image"][()] + 1) / 2
        mask = data["label"][()] == 1
        img[mask] = 0.25 * img[mask]
        ax.imshow(img)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1168/1440019714.py in <module>
#       1 n=1
# ----> 2 fig, axs = plt.subplots(r, c)
#       3 if n == 1:
#       4     axs = np.array([axs])
#       5 for filename, ax in zip(filename2, axs.flatten()):
#
# NameError: name 'r' is not defined

# %%
with h5py.File(filename, "r") as data:
    img = (data["image"][()] + 1) / 2
    mask = data["label"][()] == 1
    img[mask] = 0.25 * img[mask]
    plt.imshow(img)
plt.tight_layout()
plt.show()

# %%
! cd xfuse-2023-04-20T10\:48\:25.418334
# !xfuse init my-config.toml data.h5
# Out:
# /bin/bash: xfuse: command not found
